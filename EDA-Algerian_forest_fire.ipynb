# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
from six.moves import urllib

warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
data=pd.read_csv("D:\\RESOURSES\\algeria\\Algerian_forest_fires_dataset_UPDATE.csv")

# %%
data
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC   DMC    DC  ISI  \
# 0      1      6  2012           29   57   18    0.0  65.7   3.4   7.6  1.3
# 1      2      6  2012           29   61   13    1.3  64.4   4.1   7.6  1.0
# 2      3      6  2012           26   82   22   13.1  47.1   2.5   7.1  0.3
# 3      4      6  2012           25   89   13    2.5  28.6   1.3   6.9  0.0
# 4      5      6  2012           27   77   16    0.0  64.8   3.0  14.2  1.2
# ..   ...    ...   ...          ...  ...  ...    ...   ...   ...   ...  ...
# 239   26      9  2012           30   65   14    0.0  85.4  16.0  44.5  4.5
# 240   27      9  2012           28   87   15    4.4  41.1   6.5     8  0.1
# 241   28      9  2012           27   87   29    0.5  45.9   3.5   7.9  0.4
# 242   29      9  2012           24   54   18    0.1  79.7   4.3  15.2  1.7
# 243   30      9  2012           24   64   15    0.2  67.3   3.8  16.5  1.2
#
#       BUI  FWI     Classes                          Region
# ...

# %%
#Show top 5 records
data.head(5)
# Out:
#    day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29   57   18    0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29   61   13    1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26   82   22   13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25   89   13    2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27   77   16    0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI    Classes                   Region
# 0  0.5  not fire     Bejaia Region Dataset
# 1  0.4  not fire     Bejaia Region Dataset
# 2  0.1  not fire     Bejaia Region Dataset
# 3    0  not fire     Bejaia Region Dataset
# 4  0.5  not fire     Bejaia Region Dataset

# %%
#Shape of the data
data.shape
# Out:
# (244, 15)

# %% [markdown]
# # Summary of the dataset

# %%
# Disply summary for the dataset
data.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  244.000000  244.000000   244.0   244.000000  244.000000  244.000000
# mean    15.754098    7.500000  2012.0    32.172131   61.938525   15.504098
# std      8.825059    1.112961     0.0     3.633843   14.884200    2.810178
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.000000   14.000000
# 50%     16.000000    7.500000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.250000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#             Rain         FFMC         DMC         ISI         BUI
# count  244.000000  244.000000  244.000000  244.000000  244.000000
# mean     0.760656   77.887705   14.673361    4.774180   16.664754
# std      1.999406   14.337571   12.368039    4.175318   14.204824
# ...

# %%
data.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', ' Region '],
#       dtype='object')

# %% [markdown]
# # Check Datatypes in the dataset

# %%
#Check Null and Dtypes

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    int64
#  1   month        244 non-null    int64
#  2   year         244 non-null    int64
#  3   Temperature  244 non-null    int64
#  4    RH          244 non-null    int64
#  5    Ws          244 non-null    int64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    float64
#  11  BUI          244 non-null    float64
#  12  FWI          244 non-null    object
#  13  Classes      244 non-null    object
#  14   Region      244 non-null    object
# dtypes: float64(5), int64(6), object(4)
# memory usage: 28.7+ KB

# %%
data.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
#  Region        0
# dtype: int64

# %% [markdown]
# # Exploring Data

# %%
#define numerical & categorical columns

numeric_features = [feature for feature in data.columns if data[feature].dtype != 'O']
categorical_features = [feature for feature in data.columns if data[feature].dtype == 'O']

# %%
# print columns

print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 11 numerical features : ['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC', 'DMC', 'ISI', 'BUI']
#
# We have 4 categorical features : ['DC', 'FWI', 'Classes  ', ' Region ']

# %% [markdown]
# # Attribute Information:
#
# 1. Date : (DD/MM/YYYY) Day--->month ('june' to 'september')--> year (2012)
# Weather data observations:
# 2. Temp : temperature noon (temperature max) in Celsius degrees: 22 to 42
# 3. RH : Relative Humidity in %: 21 to 90
# 4. Ws :Wind speed in km/h: 6 to 29
# 5. Rain: total day in mm: 0 to 16.8
# FWI Components:
# 6. Fine Fuel Moisture Code (FFMC) index from the FWI system: 28.6 to 92.5
# 7. Duff Moisture Code (DMC) index from the FWI system: 1.1 to 65.9
# 8. Drought Code (DC) index from the FWI system: 7 to 220.4
# 9. Initial Spread Index (ISI) index from the FWI system: 0 to 18.5
# 10. Buildup Index (BUI) index from the FWI system: 1.1 to 68
# 11. Fire Weather Index (FWI) Index: 0 to 31.1
# 12. Classes: two classes, namely fire and not fire .

# %%
#proportion of count data on categorical columns

for col in categorical_features:
    print(data[col].value_counts(normalize=True)*100)
    print("------------------------------------------")
# Out:
# 8        2.049180
# 7.6      1.639344
# 7.8      1.639344
# 8.4      1.639344
# 7.5      1.639344
#            ...
# 90.4     0.409836
# 100.7    0.409836
# 110.9    0.409836
# 120.9    0.409836
# 16.5     0.409836
# Name: DC, Length: 198, dtype: float64
# ------------------------------------------
# 0.4     4.918033
# 0.8     4.098361
# 0.5     3.688525
# 0.1     3.688525
# 0       3.688525
#           ...
# 30.2    0.409836
# 20.3    0.409836
# 22.3    0.409836
# 20.4    0.409836
# 6.5     0.409836
# Name: FWI, Length: 126, dtype: float64
# ------------------------------------------
# fire             53.688525
# not fire         41.393443
# fire              2.049180
# fire              0.819672
# not fire          0.819672
# not fire          0.409836
# not fire          0.409836
# not fire          0.409836
# Name: Classes  , dtype: float64
# ------------------------------------------
# Bejaia Region Dataset            50.0
# Sidi-Bel Abbes Region Dataset    50.0
# ...

# %% [markdown]
# # Univariate Analysis
#
# ==> The term univariate analysis refers to the analysis of one variable prefix "Uni" means "One". The purpose of univariate analysis is to understand the distribution of values for a single variable.

# %% [markdown]
# # #Numerical Features

# %%
plt.figure(figsize=(15,15))
plt.suptitle("Univariate Analysis of Numerical Features",fontsize=20, fontweight='bold', alpha=0.8, y=1)

for i in range(0,len(numeric_features)):
    plt.subplot(5,3,i+1)
    sns.kdeplot(x=data[numeric_features[i]],shade=True, color='b')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %% [markdown]
# ## Report

# %% [markdown]
# # Categorical Features

# %%
#Categorical columns
plt.figure(figsize=(20, 15))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
cat1 = [ 'DC', 'FWI', 'Classes', 'Region']
for i in range(0, len(cat1)):
    plt.subplot(2, 2, i+1)
    sns.countplot(x = data[cat1[i]])
    plt.xlabel(cat1[i])
    plt.xticks(rotation=45)
    plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Classes'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
data.head()
# Out:
#    day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29   57   18    0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29   61   13    1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26   82   22   13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25   89   13    2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27   77   16    0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI    Classes                   Region
# 0  0.5  not fire     Bejaia Region Dataset
# 1  0.4  not fire     Bejaia Region Dataset
# 2  0.1  not fire     Bejaia Region Dataset
# 3    0  not fire     Bejaia Region Dataset
# 4  0.5  not fire     Bejaia Region Dataset

# %% [markdown]
# The dataset is converted into two parts based on Region from 123th index,we can make a new column based on the Region

# %% [markdown]
# **1-"Bejaia Region Dataset"**

# %% [markdown]
# **2-"Sidi-Bel Abbes Region Dataset"**

# %% [markdown]
# **ADD new column with region**

# %%
data.loc[:123,'Region']=0
data.loc[123:,'Region']=1
data[['Region']] = data[['Region']].astype(int)

# %%
data
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC   DMC    DC  ISI  \
# 0      1      6  2012           29   57   18    0.0  65.7   3.4   7.6  1.3
# 1      2      6  2012           29   61   13    1.3  64.4   4.1   7.6  1.0
# 2      3      6  2012           26   82   22   13.1  47.1   2.5   7.1  0.3
# 3      4      6  2012           25   89   13    2.5  28.6   1.3   6.9  0.0
# 4      5      6  2012           27   77   16    0.0  64.8   3.0  14.2  1.2
# ..   ...    ...   ...          ...  ...  ...    ...   ...   ...   ...  ...
# 239   26      9  2012           30   65   14    0.0  85.4  16.0  44.5  4.5
# 240   27      9  2012           28   87   15    4.4  41.1   6.5     8  0.1
# 241   28      9  2012           27   87   29    0.5  45.9   3.5   7.9  0.4
# 242   29      9  2012           24   54   18    0.1  79.7   4.3  15.2  1.7
# 243   30      9  2012           24   64   15    0.2  67.3   3.8  16.5  1.2
#
#       BUI  FWI     Classes                          Region   Region
# ...

# %% [markdown]
# **Relationship analysis**

# %% [markdown]
# 1)A heatmap is a graphical representation of data that uses a system of color-coding to represent different values.
#
#
# 2)using a correlation heatmap to view rlationship between variables

# %%
data.corr()
# Out:
#                       day         month  year  Temperature        RH  \
# day          1.000000e+00  2.232788e-17   NaN     0.095772 -0.074209
# month        2.232788e-17  1.000000e+00   NaN    -0.059017 -0.037884
# year                  NaN           NaN   NaN          NaN       NaN
# Temperature  9.577222e-02 -5.901677e-02   NaN     1.000000 -0.654443
#  RH         -7.420934e-02 -3.788419e-02   NaN    -0.654443  1.000000
#  Ws          4.700086e-02 -4.144673e-02   NaN    -0.278132  0.236084
# Rain        -1.122654e-01  3.532207e-02   NaN    -0.326786  0.222968
# FFMC         2.240321e-01  1.557668e-02   NaN     0.677491 -0.645658
# DMC          4.915710e-01  6.817778e-02   NaN     0.483105 -0.405133
# ISI          1.777266e-01  6.168011e-02   NaN     0.607551 -0.690637
# BUI          5.172292e-01  8.582162e-02   NaN     0.455504 -0.348587
# Region       1.373225e-02  1.107026e-02   NaN     0.273894 -0.411438
#
# ...

# %%
sns.heatmap(data.corr(),annot=True,cmap='viridis',linewidth=.1)
# Out:
# <AxesSubplot:>

# %%
data.hist(figsize=(20,14),color='b')
# Out:
# array([[<AxesSubplot:title={'center':'day'}>,
#         <AxesSubplot:title={'center':'month'}>,
#         <AxesSubplot:title={'center':'year'}>],
#        [<AxesSubplot:title={'center':'Temperature'}>,
#         <AxesSubplot:title={'center':' RH'}>,
#         <AxesSubplot:title={'center':' Ws'}>],
#        [<AxesSubplot:title={'center':'Rain '}>,
#         <AxesSubplot:title={'center':'FFMC'}>,
#         <AxesSubplot:title={'center':'DMC'}>],
#        [<AxesSubplot:title={'center':'ISI'}>,
#         <AxesSubplot:title={'center':'BUI'}>,
#         <AxesSubplot:title={'center':'Region'}>]], dtype=object)

# %%
#LINEPLOT

# %%
sns.lineplot(x='Temperature',y='day',data=data,color='g')
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='day'>

# %% [markdown]
# *A pairplot plot a pairwise relationships in a dataset. The pairplot function creates a grid of Axes such that each variable in data will be shared in the y- axis across a single row  and x- axis across a single column.

# %%
sns.pairplot(data)

# %%
sns.jointplot(x='month',y='Temperature',data=data,color='y')

# %% [markdown]
# **BAR PLOT**

# %%
plt.style.use('default')
sns.barplot(x='day',y='Temperature',data=data)
plt.title('Day vs Temperature',fontsize=15)
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.show()

# %% [markdown]
# **Defining the maximum and minimum Temperatute**

# %%
data.Temperature.max()
# Out:
# 42

# %%
data.Temperature.min()
# Out:
# 22

# %%
# PLot density plot for all features
plt.style.use('seaborn')
data.hist(bins=50, figsize=(20,15), ec = 'b')
plt.show()
